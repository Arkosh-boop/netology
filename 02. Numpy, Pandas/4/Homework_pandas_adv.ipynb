# %% [markdown]
# **Задание 1**
# Для датафрейма log из материалов занятия создайте столбец source_type по следующим правилам:
# - если источник traffic_source равен yandex или google, то в source_type ставится organic
# - для источников paid и email из России - ставим ad
# - для источников paid и email не из России - ставим other
# - все остальные варианты берем из traffic_source без изменений

# %%
import pandas as pd
import re

log = pd.read_csv('visit_log.csv', sep=';')

log['source_type'] = log['traffic_source']
log.loc[(log['region'].str.contains('Russia') & log['traffic_source'].str.contains('paid|email')), 'source_type'] = 'ad'
log.loc[(~log['region'].str.contains('Russia') & log['traffic_source'].str.contains('paid|email')), 'source_type'] = 'other'
log.loc[log['traffic_source'].str.contains('yandex|google'), 'source_type'] = 'organic'
log.sample(15)
# Out:
#         timestamp    visit_id                                 url   region  \
# 12595  1550055866  f5ce698557  https://host.ru/1afc5618562365020a  Belarus
# 15101  1550070955  8f6ca23627  https://host.ru/39fa884393666d45fc   Russia
# 1401   1549988987  f43f1c2323  https://host.ru/39fa884393666d45fc   Russia
# 3600   1550002278  967eedb2dc  https://host.ru/8e88d4703848cc0ec4   Russia
# 6674   1550020674  80951387c1  https://host.ru/9010367b0b48d2f1b9  Ukraine
# 18038  1550088856  7f5f7b6e9a  https://host.ru/23c64743ad842b9311   Russia
# 14095  1550064797  5bcf4a06d6  https://host.ru/3004a8273caeef2867  Belarus
# 11229  1550047817  270febf1a4  https://host.ru/c8d9213a31839f9a3a   Russia
# 18704  1550092946  5ad849ba13  https://host.ru/108ce4b365afb7b88e  Belarus
# 12040  1550052656  0ac65d083f  https://host.ru/ae8a036d7f44d0bcd9   Russia
# 9246   1550035889  1006f48098  https://host.ru/b8b58337d272ee7b15   Russia
# 13425  1550060716  49307d37e9  https://host.ru/da83c74e35e7806fe0   Russia
# 2794   1549997644  3ca8cd0468  https://host.ru/b8b58337d272ee7b15    China
# 8333   1550030550  711fda3068  https://host.ru/c2382eb3d6afc8d0f3   Russia
# 9687   1550038539  e8a9d4e27a  https://host.ru/108ce4b365afb7b88e  Belarus
#
#           user_id traffic_source source_type
# 12595  bd7641b5f4         google     organic
# 15101  9f74d98409           paid          ad
# 1401   99ccfa5eb8          email          ad
# 3600   1ca256a833         direct      direct
# 6674   3e66bc9871         google     organic
# 18038  d5bd87a650         direct      direct
# 14095  6baf1d3f92         google     organic
# 11229  67c68701d6         direct      direct
# 18704  ec1f0f9e93         google     organic
# 12040  34178be84b         yandex     organic
# 9246   526513eecc           paid          ad
# 13425  63bfaf63c7         direct      direct
# 2794   a4f5b8faac         direct      direct
# 8333   256c0aff87         direct      direct
# 9687   67ce930872         yandex     organic

# %% [markdown]
# **Задание 2**
# В файле URLs.txt содержатся url страниц новостного сайта. Вам необходимо отфильтровать его по адресам страниц с текстами новостей. Известно, что шаблон страницы новостей имеет внутри url следующую конструкцию: /, затем 8 цифр, затем дефис. Выполните следующие действия:
# 1. Прочитайте содержимое файла с датафрейм
# 2. Отфильтруйте страницы с текстом новостей, используя метод str.contains и регулярное выражение в соответствии с заданным шаблоном

# %%
df = pd.read_csv('URLs.txt')
pattern = r'/\d{8}-'
df.loc[df['url'].str.contains(pattern)].head()
# Out:
#                                                  url
# 3  /politics/36188461-s-marta-zhizn-rossiyan-susc...
# 4  /world/36007585-tramp-pridumal-kak-reshit-ukra...
# 5  /science/36157853-nasa-sobiraet-ekstrennuyu-pr...
# 6  /video/36001498-poyavilis-pervye-podrobnosti-g...
# 7  /world/36007585-tramp-pridumal-kak-reshit-ukra...

# %% [markdown]
# ### Домашнее задание 3
# В датафрейме data создайте столбец lemmas, в котором вычислите леммы поисковых запросов из столбца keyword. Леммы должны иметь строковый тип.

# %%
data = pd.DataFrame({
    'keyword': ['курс гривны к рублю', 'доллары в рубли', '100 долларов в рублях', 'курс рубля'],
    'shows': [125076, 114173, 97534, 53546],
})


from pymystem3 import Mystem

def lemmatizing(row):
    m = Mystem()
    lemmas = ' '.join(m.lemmatize(row)).strip()
    return lemmas

data['lemmas'] = data['keyword'].apply(lemmatizing)
data.head(10)
# Out:
#                  keyword   shows                     lemmas
# 0    курс гривны к рублю  125076  курс   гривна   к   рубль
# 1        доллары в рубли  114173         доллар   в   рубль
# 2  100 долларов в рублях   97534   100   доллар   в   рубль
# 3             курс рубля   53546               курс   рубль

# %%
type(data.loc[[1],['lemmas']].values[0][0])
# Out:
# str
