# %% [markdown]
# Задание 1.
# Напишите функцию, которая принимает на вход строку и проверяет является ли она валидным транспортным номером. Если да, то функция должна возвращать отдельно номер и регион.

# %%
import re

def nomer(inp_nomer):
    nomer_reg = r'[АВЕКМНОРСТУХABEKMHORCTYX]{1}[0-9]{3}[АВЕКМНОРСТУХABEKMHORCTYX]{2}[0-9]{2,3}'
    nomer_proverka = re.fullmatch(nomer_reg, inp_nomer, flags=re.I)
    if nomer_proverka != None:
        return nomer_proverka.group()[0:6],nomer_proverka.group()[6:]
    else:
        print('Все пропало')
    
nomer('A001AA32')
# Out:
# ('A001AA', '32')

# %% [markdown]
# Задание 2.
# Постарайтесь написать (в крайнем случае найти) самый полный шаблон для проверки e-mail адресов через регулярное выражение, которая проверяет e-mail адрес на валидность. Можно руководствоваться следующими минимальными требованиями:
#
# • адрес должен содержать специальный символ “@”, который отделяет имя пользователя почтовой системы от доменного имени;
#
# • адрес не должен содержать следующие символы: “пробел”, “,”, “:”, “;”, “!”, “#”, “%”, “*”, “(”, “)”, “=”, “+”, “{”, “}”, " " ", " ’ ", " / ", " \ " и “|”;
#
# • адрес должен состоять только из латинских символов;
#
# • после символа “@” должна быть как минимум одна “.”;
#
# • после последней точки должно быть не менее 2-х и не более 4-х символов, причем наличие цифр не допускается;
#
# • между последней точкой и символом “@” должно быть не менее 2-х символов
#
# • слева от “@” должно быть не менее четырех символов

# %%
import re

list_mail = ['koL.ob3ok@kkk.gg',
             'grusha@k11.qdd',
             'dindin@dda@1.com'   
]

def mail_check(inp):
    reg = r'[a-z\d\.\-]{4,}\@[a-z]{2,}\.[a-z]{2,4}'
    mail_proverka = re.fullmatch(reg, inp, flags=re.I)
    if mail_proverka != None:
        print(mail_proverka.group())

for mails in list_mail:
    mail_check(mails)
# Out:
# koL.ob3ok@kkk.gg

# %% [markdown]
# Напишите функцию, которая будет удалять все последовательные повторы слов из заданной строки при помощи регулярных выражений.

# %%
import re


string = "Бежал Бежал барсук барсук нашел сыр сыр сыр и убежал убежал"

print(re.sub(r'\b([^\W\d_]+)(\s+\1)+\b', r'\1', re.sub(r'\W+', ' ', string).strip(), flags=re.I))
# Out:
# Бежал барсук нашел сыр и убежал

# %% [markdown]
# Задание 4.
# Напишите функцию, которая будет проверять номер сотового телефона на валидность, если он валиден, то переводить его в формат:
# +7(xxx)-xxx-xx-xx
# ​
# Постарайтесь предусмотреть как можно больше адекватных форматов изначального ввода номера. Примеры валидных форматов:
# ​
# • +7 955 555-55-55;
# • 9555555555;
# • 8(955)555-55-55;
# • +7 955 555 55 55;
# • 7(955) 555-55-55;
# • +7 955+555+55+55.

# %%
import re

tel_nums = [
    '+7 955 115-55-55', '9555555335', '(955)552-55-55', '+7 955 555 55 55',
    '7(955) 555-55-55', '7 955+555+55+55', '+79261234567', '89261234567',
    '79261234567', '+7 926 123 45 67', '8(926)123-45-67', '732123-45-67',
    '9261234567', '79261234567', '(495)1234567', '(495) 123 45 67',
    '89261234567', '8-926-123-45-67', '8 927 1234 234', '8 927 12 12 888',
    '8 927 12 555 12', '8 927 123 8123', '+7(903)888-88-88', '8(999)99-999-99',
    '001-541-754-3010', '+8-541-754-3010', '19-49-89-636-48018',
    '+233 205599853', '+79261234567', '89261234567', '79261234567',
    '+7 926 123 45 67', '8(926)123-45-67', '9261234567', '79261234567',
    '(495)1234567', '(495) 123 45 67', '89261234567', '8-926-123-45-67',
    '8 927 1234 234', '8 927 12 12 888', '8 927 12 555 12', '8 927 123 8 123',
    '89103123167', '+7-910-221-22-22', '+7(910)-221-22-22'
]


def tel_check(phone):
    num_pattern = r'((8|\+?7)[\- ]?)?(\(?\d{3}\)?[\+\- ]?)?[\d\+\- ]{7,10}'
    number = re.fullmatch(num_pattern, phone)
    print(f'Твой текущий номер - {phone}')
    if number != None:
        telef = re.sub(r'[- _():=+]', r'', number.group())
        return re.sub(r'\d?(\d\d\d)(\d\d\d)(\d\d)(\d\d)', r'+7(\1)-\2-\3-\4',
                      telef)
    else:
        return 'А вот и нет'


for numb in tel_nums:
    print(tel_check(numb))
# Out:
# Твой текущий номер - +7 955 115-55-55
# +7(955)-115-55-55
# Твой текущий номер - 9555555335
# +7(955)-555-53-35
# Твой текущий номер - (955)552-55-55
# +7(955)-552-55-55
# Твой текущий номер - +7 955 555 55 55
# +7(955)-555-55-55
# Твой текущий номер - 7(955) 555-55-55
# +7(955)-555-55-55
# Твой текущий номер - 7 955+555+55+55
# +7(955)-555-55-55
# Твой текущий номер - +79261234567
# +7(926)-123-45-67
# Твой текущий номер - 89261234567
# +7(926)-123-45-67
# Твой текущий номер - 79261234567
# +7(926)-123-45-67
# Твой текущий номер - +7 926 123 45 67
# +7(926)-123-45-67
# Твой текущий номер - 8(926)123-45-67
# +7(926)-123-45-67
# Твой текущий номер - 732123-45-67
# +7(732)-123-45-67
# Твой текущий номер - 9261234567
# +7(926)-123-45-67
# Твой текущий номер - 79261234567
# +7(926)-123-45-67
# Твой текущий номер - (495)1234567
# +7(495)-123-45-67
# Твой текущий номер - (495) 123 45 67
# +7(495)-123-45-67
# Твой текущий номер - 89261234567
# +7(926)-123-45-67
# ...
